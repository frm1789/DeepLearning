# %% [markdown]
# <a href="https://colab.research.google.com/github/frm1789/DeepLearning/blob/main/Chapter4_Stochastic_Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision.all import *  # Importar las herramientas de visión de fastai

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define the function f(x)
def f(x):
    return x ** 2

# %%
# Plot the function
x_vals = np.linspace(-5, 5, 100)  # Create an array of x values for plotting
y_vals = f(x_vals)  # Compute the corresponding y values for the function

plt.plot(x_vals, y_vals, label='f(x) = x^2')  # Plot the function

# Highlight the point where x = -1.5
plt.scatter(-1.5, f(-1.5), color='red', label="Point (-1.5, f(-1.5))")

plt.legend()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of f(x) = x^2 with a red point at x = -1.5')

# Show the plot
plt.show()

# %%
xt = tensor(3.).requires_grad_()

# %%
yt = f(xt)
yt
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
time = torch.arange(0,20).float(); time

speed = torch.randn(20)*3 + 0.75*(time-9.5)**2 + 1
plt.scatter(time,speed);
